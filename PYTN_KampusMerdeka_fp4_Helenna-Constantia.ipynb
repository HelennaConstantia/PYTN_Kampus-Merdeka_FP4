# %% [markdown]
# # Introduction

# %% [raw]
# Projek ini bertujuan mensegmentasi kelompok-kelompok pengguna kartu kredit berdasarkan input yang tersedia pada data. Projek ini mengambil data dari https://www.kaggle.com/arjunbhasin2013/ccdata.
# Dataset tersebut merupakan data 9000 pengguna kartu kredit selama 6 bulan yang terdiri dari 18 fitur sebagai berikut :
#
# CUSTID : Identification of Credit Card holder (Categorical)
# BALANCE : Balance amount left in their account to make purchases (
# BALANCEFREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# PURCHASES : Amount of purchases made from account
# ONEOFFPURCHASES : Maximum purchase amount done in one-go
# INSTALLMENTSPURCHASES : Amount of purchase done in installment
# CASHADVANCE : Cash in advance given by the user
# PURCHASESFREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
# CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
# PURCHASESTRX : Numbe of purchase transactions made
# CREDITLIMIT : Limit of Credit Card for user
# PAYMENTS : Amount of Payment done by user
# MINIMUM_PAYMENTS : Minimum amount of payments made by user
# PRCFULLPAYMENT : Percent of full payment paid by user
# TENURE : Tenure of credit card service for user

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# # Data Loading

# %%
df=pd.read_csv('d:Hactiv8/dataset/CC GENERAL.csv')
pd.set_option('display.max.columns', None)
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                         True
# PAYMENTS                            False
# MINIMUM_PAYMENTS                     True
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %% [markdown]
# Pada fitur credit_limit dan minimum_payments terdapat missing value yang akan divisualisasikan dibawah ini

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#visualisasi missing value
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull().transpose(),
           cmap='YlGnBu',
           cbar_kws={'label':'missing data'})
plt.title('Missing Value Position', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Missing Value Position')

# %% [markdown]
# missing value pada credit_limit hanya terdapat pada 1 baris sedangkan pada fitur minimum_payment terdapat 313 baris.

# %% [markdown]
# # Data Cleaning

# %%
#Menghapus baris yang terdapat missing value
df=df.dropna()
df.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
df.shape
# Out:
# (8636, 18)

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# kolom customer id tidak digunakan untuk itu akan dihapus, kemudian indexnya akan direset

# %%
#menghapus kolom CUST_ID
df.drop(columns=['CUST_ID'], inplace=True)
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#mereset index
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3   817.714335           1.000000      16.00             16.00
# 4  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00      0.000000             0.083333
# 4                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#melihat summary statistic
df.describe().transpose()
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8636.0  1601.224893  2095.571300   0.000000
# BALANCE_FREQUENCY                 8636.0     0.895035     0.207697   0.000000
# PURCHASES                         8636.0  1025.433874  2167.107984   0.000000
# ONEOFF_PURCHASES                  8636.0   604.901438  1684.307803   0.000000
# INSTALLMENTS_PURCHASES            8636.0   420.843533   917.245182   0.000000
# CASH_ADVANCE                      8636.0   994.175523  2121.458303   0.000000
# PURCHASES_FREQUENCY               8636.0     0.496000     0.401273   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8636.0     0.205909     0.300054   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8636.0     0.368820     0.398093   0.000000
# CASH_ADVANCE_FREQUENCY            8636.0     0.137604     0.201791   0.000000
# CASH_ADVANCE_TRX                  8636.0     3.313918     6.912506   0.000000
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Distribution Plot

# %%
#menghilangkan future warnings
warnings.simplefilter(action='ignore',category=FutureWarning)
plt.figure(figsize=(10,50))

for i in range(len(df.columns)):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={"color":"b", "lw":3 ,'label':'KDE'},hist_kws={"color":'g'})
    plt.title(df.columns[i])
    
plt.tight_layout()

# %% [markdown]
# ## Boxplot

# %%
#menghilangkan future warnings
warnings.simplefilter(action='ignore',category=FutureWarning)
plt.figure(figsize=(10,50))

for i in range(len(df.columns)):
    plt.subplot(17,1,i+1)
    sns.boxplot(df[df.columns[i]])
    plt.title(df.columns[i])
    
plt.tight_layout()

# %% [markdown]
# Hampir seluruh fitur memiliki banyak outlier sehingga fitur perlu di standardisasi terlebih dahulu

# %% [markdown]
# ## Correlations

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Fitur-fitur saling berkorelasi satu sama lain bahkan beberapa fitur memiliki korelasi yang sangat tinggi yaitu mendekati 1 seperti fitur purchases dengan oneoff_purchases, cash_advance_frequency dengan cash_advance_trx, dan purchases_installment_frequency dengan purchases_frequency

# %% [markdown]
# # Data Preprocessing

# %%
#standardisasi data
scaler=StandardScaler()
df_train=scaler.fit_transform(df)
df_train.shape
# Out:
# (8636, 17)

# %%
#mencari jumlah cluster yang optimal menggunakan elbow method
scores_1 = []

range_values = range(1,20)
for i in range_values:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df_train)
    scores_1.append(kmeans.inertia_)
plt.plot(scores_1, 'bx-')
plt.style.use('ggplot')
plt.title('Finding the right number of clusters')
plt.xlabel('Clusters')
plt.ylabel('Scores') 
plt.show()

# %% [markdown]
# Dari plot tersebut dapat dilihat bahwa score tidak menurun secara linear sampai pada kluster ke-8 sehingga diputuskan untuk memilih jumlah kluster sebanyak 8

# %% [markdown]
# # Defining Model

# %%
model = KMeans(8)

# %% [markdown]
# # Model Training

# %%
model.fit(df_train)
labels=pd.DataFrame({'labels':model.labels_})
labels.head()
# Out:
#    labels
# 0       1
# 1       2
# 2       0
# 3       1
# 4       5

# %% [markdown]
# # Model Evaluation

# %%
#Menggunakan PCA untuk memvisualisasikan data
pca=PCA(n_components=2)
principal_comp=pca.fit_transform(df_train)
principal_comp
# Out:
# array([[-1.69639583, -1.12258166],
#        [-1.2156863 ,  2.43563578],
#        [ 0.9358558 , -0.38521266],
#        ...,
#        [-0.93002442, -1.84123052],
#        [-2.35600925, -0.71871911],
#        [-0.59681819, -0.44602155]])

# %%
df_pca=pd.DataFrame(data=principal_comp, columns=['pca1','pca2'])
df_pca.head()
# Out:
#        pca1      pca2
# 0 -1.696396 -1.122582
# 1 -1.215686  2.435636
# 2  0.935856 -0.385213
# 3 -1.614638 -0.724583
# 4  0.223703 -0.783620

# %%
df_pca = pd.concat([df_pca,labels], axis = 1)
df_pca.head()
# Out:
#        pca1      pca2  labels
# 0 -1.696396 -1.122582       1
# 1 -1.215686  2.435636       2
# 2  0.935856 -0.385213       0
# 3 -1.614638 -0.724583       1
# 4  0.223703 -0.783620       5

# %%
plt.figure(figsize=(10,10))
plt.style.use('ggplot')
ax = sns.scatterplot(x="pca1", y="pca2", hue = "labels", data = df_pca, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Dataset sudah cukup rapi dan hanya memiliki sedikit missing value yang dihandle dengan cara didrop
# - Banyak fitur-fitur yang berkorelasi satu sama lain dengan nilai koefisien korelasi yang tinggi bahkan mendekati 1
# - Clustering optimal pada jumlah 8 kluster
